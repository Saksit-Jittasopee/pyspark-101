# %% [markdown]
# <a href="https://colab.research.google.com/github/Saksit-Jittasopee/pyspark-101/blob/main/PySpark_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark

# %%
import pyspark
from pyspark.sql import SparkSession

# Initialize the SparkSession
spark = SparkSession.builder \
    .appName("MyFirstPySparkApp") \
    .getOrCreate()

# Example: Create a simple DataFrame
data = [("Alice", 34), ("Bob", 45), ("Catherine", 29)]
df = spark.createDataFrame(data, ["Name", "Age"])

# Show the results
df.show()

# Stop the session when finished
spark.stop()
# Out:
# +---------+---+
# |     Name|Age|
# +---------+---+
# |    Alice| 34|
# |      Bob| 45|
# |Catherine| 29|
# +---------+---+

# %%
# df_pyspark=spark.read.csv('test1.csv')
# df_pyspark

# spark.read.option('header', 'true').csv('test1.csv') - data type of header

# %%
type(df)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: long (nullable = true)

# %%
df.head
# Out:
# <bound method DataFrame.head of DataFrame[Name: string, Age: bigint]>
